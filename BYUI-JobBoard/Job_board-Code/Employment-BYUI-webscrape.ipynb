# %%
import requests
import pandas as pd

# %%
response = requests.get('https://web.byui.edu/studentemployment/api/jobs')

data_json = response.json()

data = pd.DataFrame(data_json)

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## Top 5 highest paid jobs

# %%
data.sort_values('payRate', ascending=False).head(5)[['title','payRate','workSchedule']]
# Out:
#                                     title  payRate workSchedule
# 186  Stores and Receiving Delivery Driver    11.58   8am - 12pm
# 192           Health Center Lab Assistant    11.50          NaN
# 42                        CIT112 OnlineTA    11.30
# 27                        CIT160 OnlineTA    11.30     Flexible
# 308                  CITBC102 OnlineTutor    11.30     Flexible

# %% [markdown]
# ## All Jobs that are not 'Online','TA', and 'Custodial'

# %%
print(f'''There are {data[~data.title.str.contains('TA|Custodian|Online')].shape[0]} jobs that are not Online, TA, not custodial''')

data[~data.title.str.contains('TA|Custodian|Online')].sort_values('payRate', ascending=False)[['title','payRate','workSchedule']]
# Out:
# There are 38 jobs that are not Online, TA, not custodial
#                                            title  payRate  \
# 186         Stores and Receiving Delivery Driver    11.58
# 192                  Health Center Lab Assistant    11.50
# 174                Degree Verification Mid Shift    10.70
# 169         University Aid Processing Specialist    10.50
# 5                               Email Specialist    10.40
# 4                                Chat Specialist    10.40
# 172                   Food Services Student Jobs    10.00
# 162                          Data Entry - Alumni    10.00
# 372                      Student Project Manager    10.00
# 356     Systems & Innovation: Product Specialist     9.60
# 173  Systems & Innovation: Technology Specialist     9.60
# 170                               Grounds Crew 3     9.58
# 373                       Hard Floor Team Member     9.58
# 365                              MC Event Set-Up     9.58
# 361                    BCTR Carpet Cleaning Crew     9.58
# 164                         Carpet Cleaning Crew     9.58
# 8                                 Grounds Crew 9     9.58
# 160                              Grounds Crew 16     9.58
# 177                              Grounds Crew 13     9.58
# 371                      Security-Lock up Patrol     9.50
# 203                       Video Engineering Tech     9.35
# 363                        Teleprompter Operator     9.35
# 185                       Testing Center Proctor     9.35
# 370                          Fire Safety Student     9.35
# 175                           Welding Lab Helper     9.35
# 374                               Male Art Model     9.35
# 375                             Female Art Model     9.35
# 378          Music Production Team (Music Dept.)     9.35
# 159                            Library Aide-DCAM      NaN
# 176     Recording/Post Audio Engineering Student      NaN
# 187                       Chemistry Lab Director      NaN
# 189              Executive Office Student Writer      NaN
# 201    A/V & Broadcast Productions Lighting Crew      NaN
# 202                               Remote Proctor      NaN
# 357                              Project Manager      NaN
# 358                      IT Service Desk Analyst      NaN
# 362       Mechanical Engineering Lab Coordinator      NaN
# 377                      Security-Lock up Patrol      NaN
#
#                                           workSchedule
# 186                                         8am - 12pm
# 192                                                NaN
# 174                                     11 AM-2 PM M-F
# 169      Somewhat flexible. Minimum 20 hours per week.
# 5                                              1pm-5pm
# 4                                   7am-10am, 10am-1pm
# 172                              Many Shifts Available
# 162                              Flexible - M-F 8-5 pm
# 372                                             Varies
# 356   Monday-Saturday (7 AM to 10 PM, flexible shifts)
# 173   Monday-Saturday (7 AM to 10 PM, flexible shifts)
# 170                 6:30AM- 10:30AM or 10:30AM- 2:30PM
# 373                            Monday-Friday, 8PM-11PM
# 365    M, R, F 4:30-7:30pm; T, W 4:30-6:30pm, S 6-10pm
# 361                                                NaN
# 164                      Monday-Friday, Some Saturdays
# 8                                  3-4 hours block M-F
# 160                                                NaN
# 177                                                NaN
# 371                                    evenings/nights
# 203                                                NaN
# 363                         Tuesdays- 8:30 AM-12:30 PM
# 185                                                NaN
# 370  Tuesday through Saturday 5-10p.m. - alternatin...
# 175                              Determined upon hire.
# 374                                             varies
# 375                                             varies
# 378    Varied, avg. 12 hr/week. Click for full details
# 159                                                NaN
# 176                                                NaN
# 187                                          5-7pm M-F
# 189                            Part-time or Internship
# 201                                                NaN
# 202                                                NaN
# 357                                                NaN
# 358                                                NaN
# 362       5:45 – 7:45pm M-F, *Closes 7:00pm on Mondays
# 377                                                NaN

# %%
data.dateUpdated = data.dateUpdated.dt.time

# %%
data.set_index('dateUpdated').plot()
# Out:
# <AxesSubplot:xlabel='dateUpdated'>
