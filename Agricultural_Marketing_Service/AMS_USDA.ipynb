# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://mpr.datamart.ams.usda.gov/xmlexport/export?fileType=xml'

response = requests.get(url)

# %%
soup = BeautifulSoup(response.text)

# %%
records = soup.find_all('record')

for record in records[4:]:
    try:
        print(record['class_cattle_desc'])
    except:
        print('None')
    # break

# %%
data = pd.read_csv('Data/MNRetailDatasetCSV.CSV')
# Out:
# <ipython-input-2-510152309bfe>:1: DtypeWarning: Columns (8,9,11,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Data/MNRetailDatasetCSV.CSV')

# %%
data.isna().sum()
# Out:
# LEVEL_OF_TRADE                   0
# FREQUENCY                        0
# ISSUING_OFFICE                   0
# REPORT_DATE                      0
# PROGRAM                          0
# LEVEL_1                      12648
# LEVEL_2                     106103
# LEVEL_3                     406673
# LEVEL_4                     415596
# LEVEL_5                     462833
# ORGANIC                     128360
# SPECIALTY                   396302
# UNIT                         26887
# REGION                           0
# STORES_WITH_ADS              27128
# STORE_OUTLETS               465155
# FEATURE_RATE                477817
# SPECIAL_RATE                485386
# ACTIVITY_INDEX              477450
# LOCALLY_GROWN_PERCENTAGE    481022
# WEIGHTED_AVERAGE_PRICE       26890
# PRICE_LOW                   132355
# PRICE_HIGH                  132223
# PRODUCT_QUALITY             365117
# dtype: int64

# %%
data.nunique()
# Out:
# LEVEL_OF_TRADE                 1
# FREQUENCY                      1
# ISSUING_OFFICE                 4
# REPORT_DATE                  167
# PROGRAM                        4
# LEVEL_1                       92
# LEVEL_2                      239
# LEVEL_3                       13
# LEVEL_4                       64
# LEVEL_5                       21
# ORGANIC                        2
# SPECIALTY                      2
# UNIT                          71
# REGION                         9
# STORES_WITH_ADS             7783
# STORE_OUTLETS                  9
# FEATURE_RATE                1660
# SPECIAL_RATE                 715
# ACTIVITY_INDEX              6470
# LOCALLY_GROWN_PERCENTAGE     101
# WEIGHTED_AVERAGE_PRICE      2383
# PRICE_LOW                   1150
# PRICE_HIGH                  1308
# PRODUCT_QUALITY                5
# dtype: int64

# %%
data
# Out:
#        LEVEL_OF_TRADE FREQUENCY   ISSUING_OFFICE REPORT_DATE   PROGRAM  \
# 0              RETAIL    WEEKLY      MADISON, WI   13-JAN-23     DAIRY
# 1              RETAIL    WEEKLY      MADISON, WI   13-JAN-23     DAIRY
# 2              RETAIL    WEEKLY      MADISON, WI   13-JAN-23     DAIRY
# 3              RETAIL    WEEKLY      MADISON, WI   13-JAN-23     DAIRY
# 4              RETAIL    WEEKLY      MADISON, WI   13-JAN-23     DAIRY
# ...               ...       ...              ...         ...       ...
# 492037         RETAIL    WEEKLY  IDAHO FALLS, CA   03-JAN-20  FRUITVEG
# 492038         RETAIL    WEEKLY  IDAHO FALLS, CA   03-JAN-20  FRUITVEG
# 492039         RETAIL    WEEKLY  IDAHO FALLS, CA   03-JAN-20  FRUITVEG
# 492040         RETAIL    WEEKLY  IDAHO FALLS, CA   03-JAN-20  FRUITVEG
# 492041         RETAIL    WEEKLY  IDAHO FALLS, CA   03-JAN-20  FRUITVEG
#
#         LEVEL_1           LEVEL_2 LEVEL_3 LEVEL_4 LEVEL_5  ...  \
# ...

# %%
data.STORE_OUTLETS.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
