# %%
import requests
import pandas as pd

# %%
url = 'https://jobs.marriott.com/api/jobs?page=1'
response = requests.get(url).json()

# %%
dataframe = pd.DataFrame(response['jobs'][0])

dataframe
# Out:
#                                                                        data
# additional_locations      [{'state': 'Azerbaijan', 'country': 'Azerbaija...
# apply_url                 https://ejwl.fa.us2.oraclecloud.com:443/hcmUI/...
# applyable                                                              True
# ats_code                                                  marriott-prod-orc
# brand                                                      The Ritz-Carlton
# categories                                  [{'name': 'Sales & Marketing'}]
# category                                               [ Sales & Marketing]
# city                                                                   Baku
# country                                                          Azerbaijan
# country_code                                                             AZ
# create_date                                        2023-03-28T18:17:32+0000
# ...

# %%
response['jobs'][0]
# Out:
# {'data': {'slug': '23056262',
#   'language': 'en-us',
#   'languages': ['en-us'],
#   'title': 'Guest Arrival Expert',
# ...
