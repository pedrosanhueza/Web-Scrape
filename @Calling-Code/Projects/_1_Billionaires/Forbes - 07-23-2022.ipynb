# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.forbes.com/billionaires/page-data/index/page-data.json"

response = requests.get(url)

json_data = response.json()

# %%
rows = json_data['result']['pageContext']['tableData']

# %%
tableData = {
    k: v
    for (k, v) in rows[0].items()
    if
    (k != 'person') & # dict
    (k != 'employment') & # dict
    (k != 'qas') & # two dicts
    (k != 'bios') & # list
    (k != 'abouts') & #list
    (k != 'csfDisplayFields') #list
}
tableData
# Out:
# {'name': 'Billionaires',
#  'year': 2022,
#  'month': 4,
#  'uri': 'elon-musk',
#  'rank': 1,
#  'listUri': 'billionaires',
#  'finalWorth': 219000,
#  'category': 'Automotive',
#  'otherCompensation': 0,
#  'visible': True,
#  'personName': 'Elon Musk',
#  'age': 50,
#  'country': 'United States',
#  'state': 'Texas',
#  'city': 'Austin',
#  'source': 'Tesla, SpaceX',
#  'industries': 'Automotive',
#  'countryOfCitizenship': 'United States',
#  'organization': 'Tesla',
#  'timestamp': 1664284092360,
#  'version': 1,
#  'naturalId': 'faris/5/2022/14117',
#  'position': 1,
#  'imageExists': True,
#  'selfMade': True,
#  'status': 'U',
#  'gender': 'M',
#  'birthDate': 46915200000,
#  'lastName': 'Musk',
#  'firstName': 'Elon',
#  'listDescription': "The World's Billionaires",
#  'title': 'CEO',
#  'date': 1649134860000,
#  'wealthList': False,
#  'familyList': False,
#  'selfMadeRank': 8,
#  'thumbnail': 'http://specials-images.forbesimg.com/imageserve/62d700cd6094d2c180f269b9/280x425.jpg?fit=scale&background=000000',
#  'residenceStateRegion': 'South',
#  'squareImage': 'https://specials-images.forbesimg.com/imageserve/62d700cd6094d2c180f269b9/416x416.jpg?background=000000&cropX1=0&cropX2=959&cropY1=0&cropY2=959',
#  'bioSuppress': False,
#  'suppressOnProfiles': False,
#  'premiumProfile': False,
#  'philanthropyScore': 1,
#  'embargo': False,
#  'netWorth': '$219 B'}

# %%
person = {
    list(rows[0].keys())[9]+'_'+k:v
    for (k,v) in rows[0][list(rows[0].keys())[9]].items()
}
person
# Out:
# {'person_name': 'Elon Musk',
#  'person_uri': 'elon-musk',
#  'person_imageExists': True,
#  'person_squareImage': 'https://specials-images.forbesimg.com/imageserve/62d700cd6094d2c180f269b9/416x416.jpg?background=000000&cropX1=0&cropX2=959&cropY1=0&cropY2=959'}

# %%
employment = {
    list(rows[0].keys())[33]+'_'+k:v
    for (k,v) in rows[0][list(rows[0].keys())[33]].items()
}
employment
# Out:
# {'employment_name': 'Tesla',
#  'employment_uri': 'companies/tesla',
#  'employment_title': 'CEO',
#  'employment_government': False}

# %%
rows[0]['qas']
# Out:
# [{'question': 'Innovative Leaders: 12-month Sales Growth, %',
#   'answer': '27.03',
#   'hidden': False},
#  {'question': 'Innovative Leaders: Company Innovation Premium',
#   'answer': '72.16',
#   'hidden': False}]

# %%
pd.DataFrame([tableData])
# Out:
#            name  year  month        uri  rank       listUri  finalWorth  \
# 0  Billionaires  2022      4  elon-musk     1  billionaires      219000
#
#      category  otherCompensation  visible  ... selfMadeRank  \
# 0  Automotive                  0     True  ...            8
#
#                                            thumbnail residenceStateRegion  \
# 0  http://specials-images.forbesimg.com/imageserv...                South
#
#                                          squareImage bioSuppress  \
# 0  https://specials-images.forbesimg.com/imageser...       False
#
#   suppressOnProfiles premiumProfile philanthropyScore embargo  netWorth
# 0              False          False                 1   False    $219 B
#
# [1 rows x 45 columns]

# %%
ls_=[]

for row in rows:
    tableData = {
        k: v
        for (k, v) in row.items()
        if
        (k != 'person') & # dict
        (k != 'employment') & # dict
        (k != 'qas') & # two dicts
        (k != 'bios') & # list
        (k != 'abouts') & #list
        (k != 'csfDisplayFields') #list
        }
    ls_.append(tableData)

# %%
data = pd.DataFrame(ls_)

# %%
cols_to_drop = [
    'parentListUri',
    'organization',
    'title',
    'selfMadeRank',
    'residenceStateRegion',
    'embargo',
    'residenceMsa',
    'impactInvestor',
    'numberOfSiblings',
    'numberOfSiblingsEst',
    'bio',
    'totalCharitableDonation',
    'charitableDonationPercentage',
    'thumbnail',
    'notableDeal',
    'valueCreated',
    'primaryIndustry',
    'portraitImage',
    'landscapeImage',
    'clients']

data.drop(cols_to_drop, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-01a85a670550> in <module>
#      21     'clients']
#      22
# ---> 23 data.drop(cols_to_drop, axis=1, inplace=True)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5389                 weight  1.0     0.8
#    5390         """
# -> 5391         return super().drop(
#    5392             labels=labels,
#    5393             axis=axis,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508         for axis, labels in axes.items():
#    4509             if labels is not None:
# -> 4510                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4511
#    4512         if inplace:
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4549                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4550             else:
# -> 4551                 new_axis = axis.drop(labels, errors=errors)
#    4552             indexer = axis.get_indexer(new_axis)
#    4553
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6970         if mask.any():
#    6971             if errors != "ignore":
# -> 6972                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973             indexer = indexer[~mask]
#    6974         return self.delete(indexer)
#
# KeyError: "['totalCharitableDonation', 'charitableDonationPercentage'] not found in axis"

# %%
data.isna().sum()
# Out:
# name                       0
# year                       0
# month                      0
# uri                        0
# rank                       0
# listUri                    0
# finalWorth                 0
# category                   0
# otherCompensation          0
# visible                    0
# personName                 0
# age                        0
# country                   13
# state                   1920
# city                      44
# source                     0
# industries                 0
# countryOfCitizenship       0
# organization            2321
# timestamp                  0
# version                    0
# naturalId                  0
# position                   0
# imageExists                0
# selfMade                   0
# status                     0
# gender                    16
# birthDate                 98
# lastName                   0
# firstName                  6
# listDescription            0
# title                   2278
# date                       0
# wealthList                 0
# familyList                 0
# selfMadeRank            2102
# thumbnail               2464
# residenceStateRegion    1928
# squareImage              679
# bioSuppress                0
# suppressOnProfiles         0
# premiumProfile             0
# philanthropyScore          0
# embargo                 2088
# netWorth                   0
# parentListUri            580
# residenceMsa            2043
# impactInvestor          2629
# numberOfSiblings        2541
# numberOfSiblingsEst     2541
# bio                     2603
# notableDeal             2654
# valueCreated            2648
# primaryIndustry         2667
# portraitImage           2659
# landscapeImage          2659
# clients                 2667
# dtype: int64

# %%
data
# Out:
#               name  year  month              uri  rank       listUri  \
# 0     Billionaires  2022      4        elon-musk     1  billionaires
# 1     Billionaires  2022      4       jeff-bezos     2  billionaires
# 2     Billionaires  2022      4  bernard-arnault     3  billionaires
# 3     Billionaires  2022      4       bill-gates     4  billionaires
# 4     Billionaires  2022      4   warren-buffett     5  billionaires
# ...            ...   ...    ...              ...   ...           ...
# 2663  Billionaires  2022      4    zhang-yuqiang  2578  billionaires
# 2664  Billionaires  2022      4       zhou-ruxin  2578  billionaires
# 2665  Billionaires  2022      4         wen-zhou  2578  billionaires
# 2666  Billionaires  2022      4      zhou-yifeng  2578  billionaires
# 2667  Billionaires  2022      4   zhuang-kuilong  2578  billionaires
#
#       finalWorth               category  otherCompensation  visible  \
# 0         219000             Automotive                  0     True
# 1         171000             Technology                  0     True
# 2         158000       Fashion & Retail                  0     True
# 3         129000             Technology                  0     True
# 4         118000  Finance & Investments                  0     True
# ...          ...                    ...                ...      ...
# 2663        1000          Manufacturing                  0     True
# 2664        1000             Technology                  0     True
# 2665        1000          Manufacturing                  0     True
# 2666        1000                 Energy                  0     True
# 2667        1000          Manufacturing                  0     True
#
#                     personName  age        country       state          city  \
# 0                    Elon Musk   50  United States       Texas        Austin
# 1                   Jeff Bezos   58  United States  Washington       Seattle
# 2     Bernard Arnault & family   73         France         NaN         Paris
# 3                   Bill Gates   66  United States  Washington        Medina
# 4               Warren Buffett   91  United States    Nebraska         Omaha
# ...                        ...  ...            ...         ...           ...
# 2663             Zhang Yuqiang   66          China         NaN     Tongxiang
# 2664                Zhou Ruxin   59          China         NaN       Beijing
# 2665         Wen Zhou & family   57          China         NaN      Shanghai
# 2666      Zhou Yifeng & family   43          China         NaN  Zhangjiagang
# 2667   Zhuang Kuilong & family   59          China         NaN       Jiaxing
#
#                        source             industries countryOfCitizenship  \
# 0               Tesla, SpaceX             Automotive        United States
# 1                      Amazon             Technology        United States
# 2                        LVMH       Fashion & Retail               France
# 3                   Microsoft             Technology        United States
# 4          Berkshire Hathaway  Finance & Investments        United States
# ...                       ...                    ...                  ...
# 2663               Fiberglass          Manufacturing                China
# 2664               Navigation             Technology                China
# 2665                chemicals          Manufacturing                China
# 2666  liquefied petroleum gas                 Energy                China
# 2667                polyester          Manufacturing                China
#
#                           organization      timestamp  version  \
# 0                                Tesla  1664284092360        1
# 1                               Amazon  1664284094526        1
# 2     LVMH Moët Hennessy Louis Vuitton  1649136422879        1
# 3      Bill & Melinda Gates Foundation  1664284096498        1
# 4       Berkshire Hathaway Inc. (Cl A)  1664284100407        1
# ...                                ...            ...      ...
# 2663                               NaN  1649106322824        1
# 2664                               NaN  1649106324192        1
# 2665                               NaN  1649106325939        1
# 2666                               NaN  1649106327425        1
# 2667                               NaN  1649106328778        1
#
#                 naturalId  position  imageExists  selfMade status gender  \
# 0      faris/5/2022/14117         1         True      True      U      M
# 1       faris/5/2022/6713         2         True      True      D      M
# 2       faris/5/2022/4800         3         True     False      U      M
# 3       faris/5/2022/5772         4         True      True      U      M
# 4       faris/5/2022/5381         5         True      True      U      M
# ...                   ...       ...          ...       ...    ...    ...
# 2663     faris/5/2022/736      2664        False      True      E      M
# 2664     faris/5/2022/784      2665        False      True      D      M
# 2665   faris/5/2022/12437      2666        False      True      D      M
# 2666    faris/5/2022/1275      2667        False      True      D      F
# 2667  faris/5/2022/203531      2668        False      True      D      M
#
#          birthDate lastName firstName           listDescription  \
# 0     4.691520e+10     Musk      Elon  The World's Billionaires
# 1    -1.884384e+11    Bezos      Jeff  The World's Billionaires
# 2    -6.572448e+11  Arnault   Bernard  The World's Billionaires
# 3    -4.474656e+11    Gates      Bill  The World's Billionaires
# 4    -1.241482e+12  Buffett    Warren  The World's Billionaires
# ...            ...      ...       ...                       ...
# 2663 -4.523904e+11    Zhang   Yuqiang  The World's Billionaires
# 2664 -2.158272e+11     Zhou     Ruxin  The World's Billionaires
# 2665 -1.522368e+11     Zhou       Wen  The World's Billionaires
# 2666  2.689632e+11     Zhou    Yifeng  The World's Billionaires
# 2667 -2.382048e+11   Zhuang   Kuilong  The World's Billionaires
#
#                      title           date  wealthList  familyList  \
# 0                      CEO  1649134860000       False       False
# 1     Chairman and Founder  1649134860000       False       False
# 2         Chairman and CEO  1649116800000       False       False
# 3                Cofounder  1649134860000       False       False
# 4                      CEO  1649134860000       False       False
# ...                    ...            ...         ...         ...
# 2663                   NaN  1649116800000       False       False
# 2664                   NaN  1649116800000       False       False
# 2665                   NaN  1649116800000       False       False
# 2666                   NaN  1649116800000       False       False
# 2667                   NaN  1649116800000       False       False
#
#       selfMadeRank                                          thumbnail  \
# 0              8.0  http://specials-images.forbesimg.com/imageserv...
# 1              8.0                                                NaN
# 2              NaN                                                NaN
# 3              8.0  http://specials-images.forbesimg.com/imageserv...
# 4              8.0                                                NaN
# ...            ...                                                ...
# 2663           NaN                                                NaN
# 2664           NaN                                                NaN
# 2665           NaN                                                NaN
# 2666           NaN                                                NaN
# 2667           NaN                                                NaN
#
#      residenceStateRegion                                        squareImage  \
# 0                   South  https://specials-images.forbesimg.com/imageser...
# 1                    West  https://specials-images.forbesimg.com/imageser...
# 2                     NaN  //specials-images.forbesimg.com/imageserve/5dc...
# 3                    West  https://specials-images.forbesimg.com/imageser...
# 4                 Midwest  //specials-images.forbesimg.com/imageserve/5ba...
# ...                   ...                                                ...
# 2663                  NaN                                                NaN
# 2664                  NaN                                                NaN
# 2665                  NaN                                                NaN
# 2666                  NaN                                                NaN
# 2667                  NaN                                                NaN
#
#       bioSuppress  suppressOnProfiles  premiumProfile philanthropyScore  \
# 0           False               False           False                 1
# 1           False               False           False                 1
# 2           False               False           False               N/A
# 3           False               False           False                 4
# 4           False               False           False                 5
# ...           ...                 ...             ...               ...
# 2663        False               False           False               N/A
# 2664        False               False           False               N/A
# 2665        False               False           False               N/A
# 2666        False               False           False               N/A
# 2667        False               False           False               N/A
#
#      embargo netWorth parentListUri                 residenceMsa  \
# 0      False   $219 B           NaN                          NaN
# 1      False   $171 B           NaN                          NaN
# 2        NaN   $158 B  billionaires                          NaN
# 3      False   $129 B           NaN  Seattle-Tacoma-Bellevue, WA
# 4      False   $118 B           NaN                    Omaha, NE
# ...      ...      ...           ...                          ...
# 2663     NaN     $1 B  billionaires                          NaN
# 2664     NaN     $1 B  billionaires                          NaN
# 2665     NaN     $1 B  billionaires                          NaN
# 2666     NaN     $1 B  billionaires                          NaN
# 2667     NaN     $1 B  billionaires                          NaN
#
#      impactInvestor  numberOfSiblings numberOfSiblingsEst  bio notableDeal  \
# 0               NaN               NaN                 NaN  NaN         NaN
# 1               NaN               NaN                 NaN  NaN         NaN
# 2               NaN               NaN                 NaN  NaN         NaN
# 3              True               NaN                 NaN  NaN         NaN
# 4               NaN               NaN                 NaN  NaN         NaN
# ...             ...               ...                 ...  ...         ...
# 2663            NaN               NaN                 NaN  NaN         NaN
# 2664            NaN               NaN                 NaN  NaN         NaN
# 2665            NaN               NaN                 NaN  NaN         NaN
# 2666            NaN               NaN                 NaN  NaN         NaN
# 2667            NaN               NaN                 NaN  NaN         NaN
#
#       valueCreated primaryIndustry portraitImage landscapeImage clients
# 0              NaN             NaN           NaN            NaN     NaN
# 1              NaN             NaN           NaN            NaN     NaN
# 2              NaN             NaN           NaN            NaN     NaN
# 3              NaN             NaN           NaN            NaN     NaN
# 4              NaN             NaN           NaN            NaN     NaN
# ...            ...             ...           ...            ...     ...
# 2663           NaN             NaN           NaN            NaN     NaN
# 2664           NaN             NaN           NaN            NaN     NaN
# 2665           NaN             NaN           NaN            NaN     NaN
# 2666           NaN             NaN           NaN            NaN     NaN
# 2667           NaN             NaN           NaN            NaN     NaN
#
# [2668 rows x 57 columns]
