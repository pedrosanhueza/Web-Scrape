# %%
import requests
import pandas as pd

# %%
response = requests.get('https://byui.kuali.co/api/v1/catalog/courses/6102e778ef84b869ba4eb375?q=')

responseObject = response.json()

df = pd.DataFrame(responseObject)

df = pd.concat([df, df.subjectCode.apply(pd.Series)], axis=1).drop(['subjectCode','__passedCatalogQuery','_score'], axis=1)

df
# Out:
#      __catalogCourseId   dateStart         pid  \
# 0             ACCTG100  2019-01-01   414Six2j-
# 1             ACCTG180  2020-01-01  V1g4Sol3sW
# 2             ACCTG201  2020-01-01   EkrHil3oZ
# 3             ACCTG202  2020-01-01   Vy8rsxhiW
# 4             ACCTG205  2022-01-01  NkxUrjehs-
# ...                ...         ...         ...
# 2094           WELD329  2022-01-01   4kIpgbho-
# 2095           WELD338  2017-01-01  N1g86g-hib
# 2096           WELD350  2022-01-01  EJWLTlW2jZ
# 2097           WELD480  2022-01-01  EkG86l-3s-
# 2098          WELD490R  2022-01-01   HJuZiFLSw
#
#                                         id  \
# 0                 5a6a3fb5449c7c2e00c517af
# 1                 5da0e7a7783602240012c9cb
# 2                 5da7a52d25c43024004548bf
# 3                 5da8a5c19a654a2400d2eeb3
# 4                 6202ca0aaa637727f9b984da
# ...                                    ...
# 2094              6042c80977e1c400270d89bb
# 2095  b17972a7-c38f-4b33-9a7b-3c08f8d9f86c
# 2096              6063af60b548f800261b9638
# 2097              6042c4c8639c000028829e4a
# 2098              5f690b00634e4900264af55f
#
#                                           title catalogActivationDate   name  \
# 0                    Introduction to Accounting            2018-12-21  ACCTG
# 1                          Survey of Accounting            2019-12-01  ACCTG
# 2                          Financial Accounting            2019-12-01  ACCTG
# 3                         Managerial Accounting            2019-12-01  ACCTG
# 4                           Accounting Software            2021-12-01  ACCTG
# ...                                         ...                   ...    ...
# 2094  Welding Codes, Certification & Inspection            2021-12-01   WELD
# 2095                         Welding Automation            2017-01-01   WELD
# 2096                        Physical Metallurgy            2021-12-01   WELD
# 2097                        Welding Fabrication            2021-12-01   WELD
# 2098                  Special Topics in Welding            2021-12-01   WELD
#
#      description                                    id  \
# 0     Accounting  45beaa83-7d3c-4760-bdb1-6813f94d4097
# 1     Accounting  45beaa83-7d3c-4760-bdb1-6813f94d4097
# 2     Accounting  45beaa83-7d3c-4760-bdb1-6813f94d4097
# 3     Accounting  45beaa83-7d3c-4760-bdb1-6813f94d4097
# 4     Accounting  45beaa83-7d3c-4760-bdb1-6813f94d4097
# ...          ...                                   ...
# 2094     Welding  29ee52d3-030c-4823-a922-fe830800138c
# 2095     Welding  29ee52d3-030c-4823-a922-fe830800138c
# 2096     Welding  29ee52d3-030c-4823-a922-fe830800138c
# 2097     Welding  29ee52d3-030c-4823-a922-fe830800138c
# 2098     Welding  29ee52d3-030c-4823-a922-fe830800138c
#
#                    linkedGroup
# 0     578be6e1aeb3767907f3b4e8
# 1     578be6e1aeb3767907f3b4e8
# 2     578be6e1aeb3767907f3b4e8
# 3     578be6e1aeb3767907f3b4e8
# 4     578be6e1aeb3767907f3b4e8
# ...                        ...
# 2094  59d3a033b0e9130001e8a713
# 2095  59d3a033b0e9130001e8a713
# 2096  59d3a033b0e9130001e8a713
# 2097  59d3a033b0e9130001e8a713
# 2098  59d3a033b0e9130001e8a713
#
# [2099 rows x 10 columns]

# %%
df.columns = [
    'catalogCourseId',
    'dateStart',
    'pid',
    'id',
    'title',
    'catalogActivationDate',
    'name',
    'description',
    'subjectCode-id',
    'linkedGroup'
]
